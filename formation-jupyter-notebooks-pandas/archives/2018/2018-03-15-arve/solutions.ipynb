# %% [markdown]
# # Introduction à Pandas : exercices
#
#
# ## Données d'exemple : Geonames
#
# file: http://download.geonames.org/export/dump/allCountries.zip
#
# ### Documentation
#
# The main 'geoname' table has the following fields :
#
# * geonameid : integer id of record in geonames database
# * name : name of geographical point (utf8) varchar(200)
# * asciiname : name of geographical point in plain ascii characters, varchar(200)
# * alternatenames : alternatenames, comma separated, ascii names automatically transliterated, convenience attribute from alternatename table, varchar(10000)
# * latitude : latitude in decimal degrees (wgs84)
# * longitude : longitude in decimal degrees (wgs84)
# * feature class : see http://www.geonames.org/export/codes.html, char(1)
# * feature code : see http://www.geonames.org/export/codes.html, varchar(10)
# * country code : ISO-3166 2-letter country code, 2 characters
# * cc2 : alternate country codes, comma separated, ISO-3166 2-letter country code, 200 characters
# * admin1 code : fipscode (subject to change to iso code), see exceptions below, see file admin1Codes.txt for display names of this code; varchar(20)
# * admin2 code : code for the second administrative division, a county in the US, see file admin2Codes.txt; varchar(80)
# * admin3 code : code for third level administrative division, varchar(20)
# * admin4 code : code for fourth level administrative division, varchar(20)
# * population : bigint (8 byte int)
# * elevation : in meters, integer
# * dem : digital elevation model, srtm3 or gtopo30, average elevation of 3''x3'' (ca 90mx90m) or 30''x30'' (ca 900mx900m) area in meters, integer. srtm processed by cgiar/ciat.
# * timezone : the iana timezone id (see file timeZone.txt) varchar(40)
# * modification date : date of last modification in yyyy-MM-dd format
#
# AdminCodes: Most adm1 are FIPS codes. ISO codes are used for US, CH, BE and ME. UK and Greece are using an additional level between country and fips code. The code '00' stands for general features where no specific adm1 code is defined. The corresponding admin feature is found with the same countrycode and adminX codes and the respective feature code ADMx.

# %%
import pandas as pd

df = pd.read_csv('data/allCountries.zip', header=None, delimiter='\t', compression='zip', 
                 names=('geonameid', 'name', 'asciiname', 'alternatenames', 'latitude',
                        'longitude', 'feature class', 'feature code', 'country code', 'cc2',
                        'admin1_code', 'admin2_code', 'admin3_code', 'admin4_code', 'population',
                        'elevation', 'dem', 'timezone', 'modification_date'),
                 usecols=('geonameid', 'name', 'latitude', 'longitude', 'feature class',
                          'feature code', 'country code', 'admin1_code', 'admin2_code', 'admin3_code',
                          'admin4_code', 'population', 'elevation', 'modification_date'))
df.sample(100)
# Out:
# C:\Users\IRIARTE\AppData\Local\Continuum\Miniconda3\envs\ipykernel_py3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           geonameid                               name  latitude  longitude  \
# 363228      8153449                    Cartwright Park -33.92630  150.89070
# 5292553     7433470                      Pillessawatta   7.44380   80.43550
# 9794551     5199857                  Mapleton Junction  40.85811  -78.24557
# 3918703    10458677                    Badanpur Karkha  27.04559   78.52317
# 23266       1134478                         Kōh-e Lukh  33.99211   67.20152
# 6254989     1038567                         Rio Marepa -20.07583   33.14917
# 6308870     2444385                         Gongakaïna  13.67110    3.51480
# 4730449     3164175                          Villanova  45.02597    9.99865
# 9368763     4605256                   Bell Cove Branch  35.57675  -83.89601
# 1306013     8260147                Weinfelden District  47.54237    9.15713
# 3556307     6761197                           Kadatuan  -7.04830  107.77830
# 3488316     6410953                         Desa Nampu  -7.21667  110.79111
# 627363     11283977                            Nimpara  24.31476   88.82544
# 5884195     8783686                     Cerro El Pinto  25.04400 -101.00835
# 9438791     4675832           Bowie Junior High School  30.11438  -94.12240
# 6817304     9553206                          Nordmyran  63.82259    9.97189
# 3003878     3022144                             Cuguen  48.44970   -1.66240
# 6657910     9345946                         Opptjennet  59.98713   12.26699
# 9570084     4853925  Dialysis Center of Council Bluffs  41.26305  -95.84751
# 10301265    5760925                    Willamina Creek  45.07845 -123.47594
# 7552651     1398420                         Wasil Tsah  30.99579   69.87482
# 6442263     3144494                         Nonstindan  65.43535   13.51228
# 506307     11814934                      Shandon Shoal -29.71163  153.34869
# 8999315      695889                         Radushnoye  47.82192   33.50384
# 3654667     7568179                               Seda  -8.87670  121.15500
# 4351290    11424496                         Avichcheri  13.32151   79.87361
# 4631787     7637220                               Dābū  36.46450   52.48080
# 1164634     6168296                        Trade Creek  49.95008  -91.31692
# 9376541     4613097                     Chestnut Grove  36.41338  -86.90750
# 10254489    5713985                      Big Fir Creek  42.78350 -118.71519
# ...             ...                                ...       ...        ...
# 7779874     2742646                            Assares  41.33810   -7.07600
# 10383082    5843245                       Wilson Ditch  42.61827 -110.16155
# 8518868    11710639                 Shāri‘ Ḑayf Khātūn  36.18519   37.15522
# 6072859     9531571                    Centro Pisicola  15.34708  -92.75839
# 847669       618690                        Zvyanchatka  53.75100   32.22420
# 8825666     2465250                         Sidi Salah  35.16721    8.79281
# 7574799     1421738                      Sadhwala Toba  31.71995   71.61675
# 4672449    10350223            Cheshmeh-ye Gūtī Bolāgh  38.47139   47.68562
# 2500797     2939522                          Dachskopf  51.14111   10.37387
# 11114731     989623                        Klipfontein -32.88057   24.75220
# 696072      2395491                           Attohoué   7.01667    1.71667
# 5634234     6913782                          Tidyoulal  15.15582   -0.61532
# 1672194     7657960                            Jingcun  27.83777  114.71760
# 2952407     2970524                           Vaudeurs  48.13273    3.55050
# 1511955     1918400                              Xucun  28.79444  119.77386
# 10720950    8123637      Lane County Health Department  38.48227 -100.46764
# 8923581     3573905                         Plum Mitan  10.45000  -61.11667
# 7678127    11689172                  Basti Sadiqueābād  30.36795   72.76020
# 492364      8855777                    North Dromedary -21.95059  120.14130
# 7055351     7830163                            Suikot2  28.55840   82.13810
# 5231889    11235948                          Houay Xay  16.34105  105.79349
# 4946925    11673211                    Shisenzawa Gawa  43.85862  143.51215
# 10070033    5478413                     McCauley Ranch  33.34535 -107.94199
# 9779386     5129355                       Norway Ridge  42.01591  -77.37776
# 10644023    7313956            Malvern New Life Church  31.15419  -85.52370
# 2708925      355884                      Jabal Hindūsī  25.84278   34.20226
# 2495460     2934158                             Düvier  54.01549   13.06858
# 7809154      662944                              Viile  44.16185   24.93354
# 10806138   10279373                   Lighthouse Point  30.06173  -84.27577
# 1425025     2223752                            Nkontim   3.90000   11.16667
#
#          feature class feature code country code admin1_code admin2_code  \
# 363228               L          PRK           AU           2         NaN
# 5292553              L         LCTY           LK          32         NaN
# 9794551              S          NaN           US          PA          27
# 3918703              P          PPL           IN          36         147
# 23266                T           MT           AF          05        2806
# 6254989              H          STM           MZ          10         NaN
# 6308870              P          PPL           NE           3         NaN
# 4730449              P        PPLA3           IT           5          PC
# 9368763              H          STM           US          TN           9
# 1306013              A         ADM2           CH          TG        2015
# 3556307              P          PPL           ID          30         NaN
# 3488316              A         ADM4           ID           7         NaN
# 627363               A         ADM4           BD          83        5081
# 5884195              T           MT           MX           7          30
# 9438791              S          SCH           US          TX         245
# 6817304              H         MRSH           NO          16        1627
# 3003878              P          PPL           FR          53          35
# 6657910              H          PND           NO           6         420
# 9570084              S          HSP           US          IA         155
# 10301265             H          STM           US          OR          71
# 7552651              H          WLL           PK           2         NaN
# 6442263              T           PK           NO           9        1825
# 506307               H         SHOL           AU          02         NaN
# 8999315              P          PPL           UA           4         NaN
# 3654667              P          PPL           ID          18         NaN
# 4351290              P          PPL           IN           2         NaN
# 4631787              L         LCTY           IR          35         NaN
# 1164634              H          STM           CA           8         NaN
# 9376541              P          PPL           US          TN         147
# 10254489             H          STM           US          OR          25
# ...                ...          ...          ...         ...         ...
# 7779874              P          PPL           PT           5        0410
# 10383082             H          CNL           US          WY          35
# 8518868              R           ST           SY           9         NaN
# 6072859              S         ITTR           MX           5           3
# 847669               P          PPL           BY           6         NaN
# 8825666              S          TMB           TN          02         NaN
# 7574799              H         PNDI           PK           4         NaN
# 4672449              H         SPNG           IR          32         NaN
# 2500797              T          HLL           DE          15           0
# 11114731             S          FRM           ZA           5        DC10
# 696072               P          PPL           BJ          12         NaN
# 5634234              H         WTLD           ML          08         NaN
# 1672194              P          PPL           CN           3         NaN
# 2952407              P          PPL           FR          27          89
# 1511955              P          PPL           CN           2         NaN
# 10720950             S         BLDG           US          KS         101
# 8923581              P          PPL           TT          03         NaN
# 7678127              P          PPL           PK           4         NaN
# 492364               T          HLL           AU          08       53220
# 7055351              A         ADM5           NP          MR          12
# 5231889              H         STMI           LA          20         NaN
# 4946925              H          STM           JP          12         NaN
# 10070033             S          NaN           US          NM          51
# 9779386              T         RDGE           US          NY         101
# 10644023             S           CH           US          AL          61
# 2708925              T           MT           EG           2         NaN
# 2495460              P          PPL           DE          12           0
# 7809154              P          PPL           RO          35      154013
# 10806138             T           PT           US          FL         NaN
# 1425025              T          HLL           CM          11         NaN
#
#          admin3_code  admin4_code  population  elevation modification_date
# 363228           NaN          NaN           0        NaN        2012-01-22
# 5292553          NaN          NaN           0        NaN        2010-08-07
# 9794551        66736          NaN           0      444.0        2017-05-23
# 3918703          NaN          NaN           0        NaN        2016-02-11
# 23266            NaN          NaN           0     3380.0        2018-02-17
# 6254989          NaN          NaN           0        NaN        2012-01-19
# 6308870          NaN          NaN           0        NaN        2012-01-18
# 4730449        33046          NaN        1000       42.0        2014-04-13
# 9368763          NaN          NaN           0      531.0        2006-01-15
# 1306013          NaN          NaN       51756        NaN        2017-09-13
# 3556307          NaN          NaN           0        NaN        2012-01-20
# 3488316          NaN  6.41095e+06           0        NaN        2012-01-20
# 627363        508125  5.08126e+07           0        NaN        2016-11-06
# 5884195          NaN          NaN           0        NaN        2015-06-22
# 9438791          NaN          NaN           0        9.0        2006-01-15
# 6817304          NaN          NaN           0        NaN        2014-09-17
# 3003878          354        35092           0        NaN        2016-02-18
# 6657910          NaN          NaN           0        NaN        2014-08-14
# 9570084        92292          NaN           0      310.0        2017-05-23
# 10301265         NaN          NaN           0       67.0        2010-02-17
# 7552651          NaN          NaN           0        NaN        2018-03-08
# 6442263          NaN          NaN           0        NaN        2014-05-29
# 506307           NaN          NaN           0        NaN        2018-02-08
# 8999315          NaN          NaN           0        NaN        2011-07-28
# 3654667          NaN          NaN           0        NaN        2012-01-21
# 4351290          NaN          NaN           0        NaN        2017-01-07
# 4631787          NaN          NaN           0        NaN        2012-01-21
# 1164634          NaN          NaN           0        NaN        2006-01-18
# 9376541          NaN          NaN           0      224.0        2006-01-15
# 10254489         NaN          NaN           0     1833.0        2006-01-15
# ...              ...          ...         ...        ...               ...
# 7779874        41001          NaN           0        NaN        2011-08-28
# 10383082         NaN          NaN           0     2152.0        2006-01-15
# 8518868          NaN          NaN           0        NaN        2017-10-06
# 6072859          NaN          NaN           0        NaN        2015-06-22
# 847669           NaN          NaN           0        NaN        2012-05-05
# 8825666          NaN          NaN           0        NaN        2012-01-18
# 7574799          NaN          NaN           0        NaN        2017-10-05
# 4672449          NaN          NaN           0        NaN        2015-07-05
# 2500797        16064  1.60641e+07           0        NaN        2015-09-05
# 11114731       EC103          NaN           0        NaN        2012-07-12
# 696072           NaN          NaN           0        NaN        2016-12-28
# 5634234          NaN          NaN           0        NaN        2012-12-06
# 1672194          NaN          NaN           0        NaN        2012-01-21
# 2952407          893        89432         491        NaN        2016-02-18
# 1511955          NaN          NaN           0        NaN        2012-01-19
# 10720950       18075          NaN           0      843.0        2017-05-23
# 8923581          NaN          NaN           0        NaN        2012-08-04
# 7678127          NaN          NaN           0        NaN        2017-09-06
# 492364           NaN          NaN           0        NaN        2014-04-10
# 7055351           55       550044           0        NaN        2012-02-08
# 5231889          NaN          NaN           0        NaN        2016-08-05
# 4946925          NaN          NaN           0        NaN        2017-09-06
# 10070033         NaN          NaN           0     2178.0        2010-02-16
# 9779386          NaN          NaN           0      603.0        2010-09-05
# 10644023         NaN          NaN           0       96.0        2011-01-10
# 2708925          NaN          NaN           0        NaN        2012-01-19
# 2495460        13075  1.30751e+07         564        NaN        2015-09-05
# 7809154          NaN          NaN           8        NaN        2013-04-20
# 10806138         NaN          NaN           0        NaN        2015-05-14
# 1425025          NaN          NaN           0        NaN        2011-03-06
#
# [100 rows x 14 columns]

# %% [markdown]
# ### Question 1
#
# Quel est la taille du DataFrame?

# %%
df.shape
# Out:
# (11223939, 14)

# %% [markdown]
# ### Question 2
#
# Afficher le résumé des veleurs du DataFrame

# %%
df.describe()
# Out:
#           geonameid      latitude     longitude    population     elevation
# count  1.122394e+07  1.122394e+07  1.122394e+07  1.122394e+07  1.896643e+06
# mean   5.977588e+06  2.802339e+01  1.573290e+01  4.314742e+03  6.132599e+02
# std    3.478719e+06  2.399611e+01  7.960727e+01  2.713547e+06  7.591880e+02
# min    3.000000e+00 -9.000000e+01 -1.799995e+02 -1.200000e+01 -1.091100e+04
# 25%    2.856926e+06  1.602446e+01 -7.133146e+01  0.000000e+00  1.150000e+02
# 50%    6.142573e+06  3.277977e+01  1.930469e+01  0.000000e+00  2.880000e+02
# 75%    9.005668e+06  4.423992e+01  8.217470e+01  0.000000e+00  8.400000e+02
# max    1.183697e+07  9.000000e+01  1.800000e+02  6.814400e+09  8.848000e+03

# %% [markdown]
# ### Question 3
#
# Quels sont les lacs qui figurent dans les données? (*aide : code "LK"*)
#
# *Bonus : Y a-t-il des doublons ? *

# %%
lacs = df.loc[df['feature code'] == 'LK']
lacs[['geonameid', 'name', 'country code']].sort_values(by='name')
# Out:
#           geonameid                    name country code
# 6492795     9039959              1.Porsvatn           NO
# 10356778    5816742        1000 Island Lake           US
# 880281      5881640           101 Mile Lake           CA
# 880283      5881642           103 Mile Lake           CA
# 880285      5881644           105 Mile Lake           CA
# 880288      5881647           108 Mile Lake           CA
# 880301      5881660           130 Mile Lake           CA
# 880307      5881666        16 1/2 Mile Lake           CA
# 880309      5881668                180 Lake           CA
# 9111983     4099011       1927 Cut-off Lake           US
# 6420085     7115020               1e Diemen           NL
# 880320      5881680            24 Mile Lake           CA
# 10124896    5583683            26 Mile Lake           US
# 880323      5881683            28 Mile Lake           CA
# 6420086     7115021               2e Diemen           NL
# 880340      5881701             4 Mile Lake           CA
# 880338      5881699                 49 Lake           CA
# 880342      5881703                 51 Lake           CA
# 880345      5881706                 54 Lake           CA
# 880347      5881708                 55 Lake           CA
# 880353      5881714             6 Mile Lake           CA
# 880357      5881719                  7e Lac           CA
# 880363      5881725                  9e Lac           CA
# 9158202     4145526         A A Hilton Pond           US
# 9158205     4145529      A Bar H Ranch Pond           US
# 9158217     4145541    A J Kennedy Pond One           US
# 9158218     4145542    A J Kennedy Pond Two           US
# 9158219     4145543        A J Spencer Pond           US
# 881654      5883022                  A Lake           CA
# 9432560     4669559                  A Lake           US
# ...             ...                     ...          ...
# 8594305     6692153            ทะเลสาบสงขลา           TH
# 38679       1348156            Ḏanḏ-e Zenōr           AF
# 67217       1465246              Ḩalqah Kōl           AF
# 76803       1476562            Ḩowẕ-e Bōkōs           AF
# 32696       1143984  Ḩowẕ-e Darah-ye Kishtī           AF
# 68351       1466797   Ḩowẕ-e Darah-ye Sakhī           AF
# 70861       1469355             Ḩowẕ-e Ghāt           AF
# 60116       1456012  Ḩowẕ-e Ghāt-e Chashmah           AF
# 60110       1456004  Ḩowẕ-e Ghāt-e Sêpirmay           AF
# 60114       1456008   Ḩowẕ-e Ghāt-e Warmanā           AF
# 29800       1141065           Ḩowẕ-e Ghūjān           AF
# 60097       1455990         Ḩowẕ-e Kamanduk           AF
# 26098       1137336          Ḩowẕ-e Khakhun           AF
# 58635       1454504             Ḩowẕ-e Khāş           AF
# 73251       1471900             Ḩowẕ-e Khāş           AF
# 44493       1427716       Ḩowẕ-e Kāfarzadah           AF
# 45928       1429524       Ḩowẕ-e Muhim Khān           AF
# 21155       1132348              Ḩowẕ-e Nār           AF
# 60067       1455959           Ḩowẕ-e Rowunj           AF
# 60068       1455960        Ḩowẕ-e Sangbōnah           AF
# 15797       1126948          Ḩowẕ-e Sar Jar           AF
# 68052       1466493             Ḩowẕ-e Shōr           AF
# 10502       1121582          Ḩowẕ-e Wīghnān           AF
# 8275508      373699                Ḩumayyir           SD
# 8280433      380294        ‘Adad al Gauwala           SD
# 2836942      344269          ‘Alemaya Hāyk’           ET
# 10393582    5853862             ‘Uko‘a Pond           US
# 6401874     2746515           ’t Bovenwater           NL
# 6401613     2746244       ’t Nije Hemelriek           NL
# 1550876     6252031                     七里湖           CN
#
# [248604 rows x 3 columns]

# %%
# compraraison avec le nombre de IDs uniques
lacs['geonameid'].nunique()
# Out:
# 248604

# %% [markdown]
# ### Question 4
#
# Afficher le nombre de lacs par pays

# %%
lacs_par_pays = lacs['country code'].value_counts()
lacs_par_pays
# Out:
# CA    104662
# US     51351
# RU     16216
# NO     12454
# SE     10863
# FI      4947
# MZ      4033
# AU      3805
# PE      3479
# DE      2517
# LT      2360
# KZ      1800
# BR      1581
# ID      1537
# IE      1404
# MX      1261
# AR      1220
# CO      1209
# CN      1166
# NZ      1157
# CH      1132
# PL      1062
# VE      1013
# IN       979
# BY       725
# IS       607
# CL       567
# GB       560
# BO       559
# LV       546
#        ...
# MH         3
# LB         3
# UM         3
# BN         2
# GQ         2
# GU         2
# FM         2
# SR         2
# DM         2
# TT         2
# KI         2
# LI         2
# WF         2
# JM         2
# SG         2
# MV         1
# JO         1
# YE         1
# NR         1
# LS         1
# HK         1
# GW         1
# DJ         1
# CW         1
# KN         1
# MF         1
# VC         1
# JE         1
# BW         1
# GF         1
# Name: country code, dtype: int64

# %% [markdown]
# ### Question 5
#
# Quels sont les lacs repertoriés pour la Suisse et quel est son altitude moyenne ?
#
# *Bonus : Et pour le Canton de Genève ?*

# %%
lacs_ch = lacs.loc[lacs['country code'] == 'CH']
lacs_ch.sort_values(by='name')
# Out:
#          geonameid              name  latitude  longitude feature class  \
# 1339215   11396381        Aatalweier  47.23978    8.95145             H
# 1339082   11396247      Acqua Fredda  46.42735    8.54427             H
# 1339953   11397122       Adligeweier  47.09082    8.28545             H
# 1339885   11397054         Albulasee  46.58389    9.84796             H
# 1339962   11397131     Allmendweiher  47.30588    7.84221             H
# 1340065   11397234     Allmendweiher  47.30547    7.84349             H
# 1339344   11396511        Alpler See  46.90045    8.79126             H
# 1340025   11397194        Alpler See  46.93539    8.65419             H
# 1339821   11396990     Alte Rhein Au  47.40162    9.65605             H
# 1339202   11396368         Alte Zihl  47.13747    7.33330             H
# 1339782   11396951         Alteinsee  46.75053    9.70120             H
# 1339126   11396291       Alter Rhein  47.36866    9.64664             H
# 1339924   11397093     Ampervreilsee  46.57165    9.15126             H
# 1288160    2661754    Amsoldingersee  46.72421    7.57641             H
# 1339329   11396496         Anderbach  47.62940    9.02040             H
# 1340069   11397238        Antseeuwen  46.65548    8.09443             H
# 1339919   11397088        Antseeuwen  46.65539    8.09625             H
# 1339267   11396434        Antseeuwen  46.65591    8.09320             H
# 1339718   11396886            Anusee  46.45581    7.91299             H
# 1288125    2661718          Arnensee  46.38921    7.21664             H
# 1339474   11396642           Arnisee  46.77186    8.64316             H
# 1340058   11397227         Arniseeli  46.79040    8.08562             H
# 1339608   11396776         Arveseeli  46.44360    7.63603             H
# 1339586   11396754         Arveseeli  46.44391    7.63659             H
# 1340095   11397264           Aspisee  47.20713    7.81654             H
# 1339986   11397155    Augstbergseeli  46.87993   10.02898             H
# 1295538    6695185             Ausee  47.24839    8.64015             H
# 1339158   11396324           Bachsee  46.66952    8.02130             H
# 1339056   11396221     Bachtelweiher  47.29578    8.89828             H
# 1339389   11396556       Baggerseeli  46.69127    7.88925             H
# ...            ...               ...       ...        ...           ...
# 1339612   11396780      Weisshornsee  46.37259    7.47611             H
# 1339249   11396416     Wenigerweiher  47.41848    9.41390             H
# 1339677   11396845  Werdenberger See  47.16714    9.46380             H
# 1339878   11397047         Wichelsee  46.92052    8.27387             H
# 1339837   11397006             Wijer  46.96091    8.57463             H
# 1340032   11397201   Wildenmattensee  46.58554    8.66098             H
# 1340030   11397199     Wildertweiher  47.39640    8.72459             H
# 1339115   11396280          Wilersee  47.17107    8.61889             H
# 1339422   11396589         Wirbulsee  46.46326    8.16090             H
# 1339526   11396694         Wysse See  46.36884    7.68215             H
# 1339978   11397147          Wyssesee  46.74972    8.08088             H
# 1339332   11396499    Wäbereggweiher  47.28810    8.93511             H
# 1284576    2658079      Wägitalersee  47.08935    8.92191             H
# 1339679   11396847         Wäschtsee  46.25810    7.62245             H
# 1339103   11396268      Zervreilasee  46.56898    9.10185             H
# 1284382    2657883         Zuger See  47.13130    8.48335             H
# 1339927   11397096        Zweite See  46.22751    8.11773             H
# 1340021   11397190            Züesee  46.34674    8.24533             H
# 1284391    2657892         Zürichsee  47.23129    8.70336             H
# 1339055   11396220           Ägelsee  46.64781    7.54249             H
# 1339955   11397124           Ägelsee  47.56618    7.87965             H
# 1339971   11397140           Ägelsee  47.40072    8.35962             H
# 1288240    2661840          Ägerisee  47.12347    8.61867             H
# 1339982   11397151          Älplisee  46.75319    9.64331             H
# 1340015   11397184       Älprigensee  46.62845    8.48313             H
# 1339750   11396918  Änggelaueneseeli  46.89547    8.06167             H
# 1339810   11396979         Ängiwäier  47.70220    8.60738             H
# 1339330   11396497        Übeschisee  46.73393    7.56498             H
# 1339489   11396657           Üelisee  46.53292    8.28613             H
# 1339922   11397091   Üssersts Seewji  46.23859    7.80638             H
#
#         feature code country code admin1_code admin2_code admin3_code  \
# 1339215           LK           CH          SG        1726        3342
# 1339082           LK           CH          TI        2108        5310
# 1339953           LK           CH          LU         313        1024
# 1339885           LK           CH          GR        1846        3785
# 1339962           LK           CH          SO        1108        2578
# 1340065           LK           CH          SO        1108        2578
# 1339344           LK           CH          UR         400        1219
# 1340025           LK           CH          UR         400        1217
# 1339821           LK           CH          SG        1723        3234
# 1339202           LK           CH          BE         242         746
# 1339782           LK           CH          GR        1848        3921
# 1339126           LK           CH          SG        1723        3234
# 1339924           LK           CH          GR        1850        3603
# 1288160           LK           CH          00         NaN         NaN
# 1339329           LK           CH          TG        2012        4816
# 1340069           LK           CH          BE         250         576
# 1339919           LK           CH          BE         250         576
# 1339267           LK           CH          BE         250         576
# 1339718           LK           CH          VS        2309        6192
# 1288125           LK           CH          BE         NaN         NaN
# 1339474           LK           CH          UR         400        1209
# 1340058           LK           CH          OW         600        1403
# 1339608           LK           CH          BE         249         565
# 1339586           LK           CH          BE         249         565
# 1340095           LK           CH          BE         244         334
# 1339986           LK           CH          GR        1849        3871
# 1295538           LK           CH          ZH         NaN         NaN
# 1339158           LK           CH          BE         250         576
# 1339056           LK           CH          ZH         105         120
# 1339389           LK           CH          BE         250         572
# ...              ...          ...         ...         ...         ...
# 1339612           LK           CH          VS        2311        6239
# 1339249           LK           CH          SG        1721        3203
# 1339677           LK           CH          SG        1724        3271
# 1339878           LK           CH          OW         600        1407
# 1339837           LK           CH          UR         400        1215
# 1340032           LK           CH          UR         400        1202
# 1340030           LK           CH          ZH         108         174
# 1339115           LK           CH          ZG         900        1704
# 1339422           LK           CH          VS        2304        6052
# 1339526           LK           CH          VS        2306        6117
# 1339978           LK           CH          BE         250         580
# 1339332           LK           CH          SG        1726        3342
# 1284576           LK           CH          SZ         NaN         NaN
# 1339679           LK           CH          VS        2306        6110
# 1339103           LK           CH          GR        1850        3603
# 1284382           LK           CH          00         NaN         NaN
# 1339927           LK           CH          VS        2301        6011
# 1340021           LK           CH          VS        2304        6054
# 1284391           LK           CH          00         NaN         NaN
# 1339055           LK           CH          BE         249         762
# 1339955           LK           CH          AG        1909        4263
# 1339971           LK           CH          AG        1902        4023
# 1288240           LK           CH          00         NaN         NaN
# 1339982           LK           CH          GR        1848        3921
# 1340015           LK           CH          UR         400        1208
# 1339750           LK           CH          LU         316        1004
# 1339810           LK           CH          SH        1403        2939
# 1339330           LK           CH          BE         247         770
# 1339489           LK           CH          VS        2304        6076
# 1339922           LK           CH          VS        2313        6296
#
#         admin4_code  population  elevation modification_date
# 1339215         NaN           0        NaN        2016-12-27
# 1339082         NaN           0        NaN        2016-12-27
# 1339953         NaN           0        NaN        2016-12-27
# 1339885         NaN           0        NaN        2017-07-28
# 1339962         NaN           0        NaN        2016-12-27
# 1340065         NaN           0        NaN        2016-12-27
# 1339344         NaN           0        NaN        2016-12-27
# 1340025         NaN           0        NaN        2016-12-27
# 1339821         NaN           0        NaN        2016-12-27
# 1339202         NaN           0        NaN        2016-12-27
# 1339782         NaN           0        NaN        2017-07-28
# 1339126         NaN           0        NaN        2016-12-27
# 1339924         NaN           0        NaN        2017-07-28
# 1288160         NaN           0        NaN        2012-01-17
# 1339329         NaN           0        NaN        2016-12-27
# 1340069         NaN           0        NaN        2016-12-27
# 1339919         NaN           0        NaN        2016-12-27
# 1339267         NaN           0        NaN        2016-12-27
# 1339718         NaN           0        NaN        2016-12-27
# 1288125         NaN           0        NaN        2007-07-03
# 1339474         NaN           0        NaN        2016-12-27
# 1340058         NaN           0        NaN        2016-12-27
# 1339608         NaN           0        NaN        2016-12-27
# 1339586         NaN           0        NaN        2016-12-27
# 1340095         NaN           0        NaN        2016-12-27
# 1339986         NaN           0        NaN        2017-07-28
# 1295538         NaN           0      405.0        2008-07-18
# 1339158         NaN           0        NaN        2016-12-27
# 1339056         NaN           0        NaN        2016-12-27
# 1339389         NaN           0        NaN        2016-12-27
# ...             ...         ...        ...               ...
# 1339612         NaN           0        NaN        2016-12-27
# 1339249         NaN           0        NaN        2016-12-27
# 1339677         NaN           0        NaN        2016-12-27
# 1339878         NaN           0        NaN        2016-12-27
# 1339837         NaN           0        NaN        2016-12-27
# 1340032         NaN           0        NaN        2016-12-27
# 1340030         NaN           0        NaN        2016-12-27
# 1339115         NaN           0        NaN        2016-12-27
# 1339422         NaN           0        NaN        2016-12-27
# 1339526         NaN           0        NaN        2016-12-27
# 1339978         NaN           0        NaN        2016-12-27
# 1339332         NaN           0        NaN        2016-12-27
# 1284576         NaN           0        NaN        2015-09-06
# 1339679         NaN           0        NaN        2016-12-27
# 1339103         NaN           0        NaN        2017-07-28
# 1284382         NaN           0      413.0        2012-02-01
# 1339927         NaN           0        NaN        2016-12-27
# 1340021         NaN           0        NaN        2016-12-27
# 1284391         NaN           0      406.0        2011-12-16
# 1339055         NaN           0        NaN        2016-12-27
# 1339955         NaN           0        NaN        2016-12-27
# 1339971         NaN           0        NaN        2016-12-27
# 1288240         NaN           0        NaN        2012-01-17
# 1339982         NaN           0        NaN        2017-07-28
# 1340015         NaN           0        NaN        2016-12-27
# 1339750         NaN           0        NaN        2016-12-27
# 1339810         NaN           0        NaN        2016-12-27
# 1339330         NaN           0        NaN        2016-12-27
# 1339489         NaN           0        NaN        2016-12-27
# 1339922         NaN           0        NaN        2016-12-27
#
# [1132 rows x 14 columns]

# %%
lacs_ch['elevation'].mean()
# Out:
# 578.94444444444446

# %%
lacs['elevation'].mean()
# Out:
# 723.26874891415559

# %%
lacs_ch.loc[lacs_ch['admin1_code'] == 'GE']
# Out:
#          geonameid                     name  latitude  longitude  \
# 1339089   11396254  Etang du Moulin de Vert  46.18096    6.02112
# 1339092   11396257  Etang du Moulin de Vert  46.18023    6.02105
# 1339758   11396926         Barrage du Rhône  46.19614    6.04785
#
#         feature class feature code country code admin1_code admin2_code  \
# 1339089             H           LK           CH          GE        2500
# 1339092             H           LK           CH          GE        2500
# 1339758             H           LK           CH          GE        2500
#
#         admin3_code admin4_code  population  elevation modification_date
# 1339089        6609         NaN           0        NaN        2016-12-27
# 1339092        6609         NaN           0        NaN        2016-12-27
# 1339758        6638         NaN           0        NaN        2016-12-27

# %%
lacs_ch.loc[lacs_ch['admin1_code'] == 'GE']['elevation'].mean()
# Out:
# nan

# %% [markdown]
# ### Question 6
#
# Identifier le lac Léman

# %%
lacs[lacs['name'].str.contains('Geneva')].sort_values(by='name')
# Out:
#           geonameid                name  latitude  longitude feature class  \
# 958757      5960266         Geneva Lake  46.76451  -81.54622             H
# 958758      5960267         Geneva Lake  53.49639 -111.18333             H
# 10014696    5422870         Geneva Lake  39.57063 -105.82117             H
# 10014689    5422863         Geneva Lake  39.09698 -107.07756             H
# 10229871    5689265         Lake Geneva  46.84090 -100.02012             H
# 10194830    5653983         Lake Geneva  48.98167 -115.41216             H
# 10194829    5653982         Lake Geneva  45.25162 -113.65567             H
# 9853641     5259170         Lake Geneva  42.56501  -88.50375             H
# 9768457     5118401         Lake Geneva  41.92841  -73.72466             H
# 9678429     5027791         Lake Geneva  45.89931  -95.32744             H
# 9169307     4156667         Lake Geneva  28.74405  -81.10875             H
# 9169306     4156666         Lake Geneva  28.14924  -81.60677             H
# 9169305     4156665         Lake Geneva  28.18799  -82.57312             H
# 9169304     4156664         Lake Geneva  28.92979  -81.67074             H
# 9169303     4156663         Lake Geneva  28.88063  -81.91585             H
# 9169302     4156662         Lake Geneva  28.50295  -82.18297             H
# 9169301     4156661         Lake Geneva  29.76608  -82.02260             H
# 9077017     4063948         Lake Geneva  31.02712  -85.84967             H
# 1287079     2660647         Lake Geneva  46.43774    6.46906             H
# 10335519    5795351         Lake Geneva  47.29153 -122.28131             H
# 10365882    5825907         Lake Geneva  44.46602 -107.25162             H
# 9174890     4162269  Little Lake Geneva  29.79779  -82.00473             H
#
#          feature code country code admin1_code admin2_code admin3_code  \
# 958757             LK           CA           8        3552         NaN
# 958758             LK           CA           1         NaN         NaN
# 10014696           LK           US          CO          19         NaN
# 10014689           LK           US          CO          51         NaN
# 10229871           LK           US          ND          43         NaN
# 10194830           LK           US          MT          53         NaN
# 10194829           LK           US          MT           1         NaN
# 9853641            LK           US          WI         127         NaN
# 9768457            LK           US          NY          27         NaN
# 9678429            LK           US          MN          41         NaN
# 9169307            LK           US          FL         117         NaN
# 9169306            LK           US          FL         105         NaN
# 9169305            LK           US          FL         101         NaN
# 9169304            LK           US          FL          69         NaN
# 9169303            LK           US          FL          69         NaN
# 9169302            LK           US          FL          53         NaN
# 9169301            LK           US          FL          19         NaN
# 9077017            LK           US          AL          61         NaN
# 1287079            LK           CH          00         NaN         NaN
# 10335519           LK           US          WA          33         NaN
# 10365882           LK           US          WY          19         NaN
# 9174890            LK           US          FL          19         NaN
#
#          admin4_code  population  elevation modification_date
# 958757           NaN           0        NaN        2018-01-20
# 958758           NaN           0        NaN        2013-07-21
# 10014696         NaN           0     3537.0        2011-12-11
# 10014689         NaN           0     3335.0        2011-12-11
# 10229871         NaN           0      550.0        2014-10-08
# 10194830         NaN           0     1995.0        2014-10-07
# 10194829         NaN           0     2577.0        2011-12-11
# 9853641          NaN           0      263.0        2014-10-08
# 9768457          NaN           0      149.0        2011-12-11
# 9678429          NaN           0      412.0        2011-12-11
# 9169307          NaN           0        8.0        2011-12-11
# 9169306          NaN           0       34.0        2014-10-07
# 9169305          NaN           0       16.0        2011-12-11
# 9169304          NaN           0       22.0        2011-12-11
# 9169303          NaN           0       25.0        2014-10-07
# 9169302          NaN           0       17.0        2014-10-07
# 9169301          NaN           0       30.0        2007-02-14
# 9077017          NaN           0       28.0        2011-12-11
# 1287079          NaN           0      372.0        2011-02-23
# 10335519         NaN           0      113.0        2011-12-12
# 10365882         NaN           0     2831.0        2013-03-08
# 9174890          NaN           0       23.0        2016-12-06

# %%
lacs[(lacs['name'].str.contains('Geneva')) & (lacs['country code'] == 'CH')].sort_values(by='name')
# Out:
#          geonameid         name  latitude  longitude feature class  \
# 1287079    2660647  Lake Geneva  46.43774    6.46906             H
#
#         feature code country code admin1_code admin2_code admin3_code  \
# 1287079           LK           CH          00         NaN         NaN
#
#         admin4_code  population  elevation modification_date
# 1287079         NaN           0      372.0        2011-02-23

# %%
lacs[lacs['geonameid'] == 2660647]
# Out:
#          geonameid         name  latitude  longitude feature class  \
# 1287079    2660647  Lake Geneva  46.43774    6.46906             H
#
#         feature code country code admin1_code admin2_code admin3_code  \
# 1287079           LK           CH          00         NaN         NaN
#
#         admin4_code  population  elevation modification_date
# 1287079         NaN           0      372.0        2011-02-23

# %% [markdown]
# ### Question 7
#
# Exporter la table des lacs dans un fichier CSV

# %%
lacs.to_csv('data/lacs.tsv', sep='\t', encoding='utf-8', index=False)

# %% [markdown]
# ### Question 8
#
# Afficher un graphique des barres avec le nombre de lacs par pays pour les premiers 30 pays
#
# *Bonus : Afficher un histogramme avec l'altitude des lacs et la même chose pour les lacs de Suisse*

# %%
import matplotlib as plt  
# %matplotlib inline

lacs_par_pays[0:30].plot.bar()

# %%
lacs['elevation'].plot.hist()

# %%
# idem pour la Suisse
lacs_ch['elevation'].plot.hist()
