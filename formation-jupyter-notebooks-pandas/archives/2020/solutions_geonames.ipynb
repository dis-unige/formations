# %% [markdown]
# # Introduction à Pandas : exercices
#
#
# ## Données d'exemple : Geonames
#
# file: allCountries.zip source: http://download.geonames.org/export/
#
# ### Documentation
#
# The main 'geoname' table has the following fields :
#
# * geonameid : integer id of record in geonames database
# * name : name of geographical point (utf8) varchar(200)
# * asciiname : name of geographical point in plain ascii characters, varchar(200)
# * alternatenames : alternatenames, comma separated, ascii names automatically transliterated, convenience attribute from alternatename table, varchar(10000)
# * latitude : latitude in decimal degrees (wgs84)
# * longitude : longitude in decimal degrees (wgs84)
# * feature class : see http://www.geonames.org/export/codes.html, char(1)
# * feature code : see http://www.geonames.org/export/codes.html, varchar(10)
# * country code : ISO-3166 2-letter country code, 2 characters
# * cc2 : alternate country codes, comma separated, ISO-3166 2-letter country code, 200 characters
# * admin1 code : fipscode (subject to change to iso code), see exceptions below, see file admin1Codes.txt for display names of this code; varchar(20)
# * admin2 code : code for the second administrative division, a county in the US, see file admin2Codes.txt; varchar(80)
# * admin3 code : code for third level administrative division, varchar(20)
# * admin4 code : code for fourth level administrative division, varchar(20)
# * population : bigint (8 byte int)
# * elevation : in meters, integer
# * dem : digital elevation model, srtm3 or gtopo30, average elevation of 3''x3'' (ca 90mx90m) or 30''x30'' (ca 900mx900m) area in meters, integer. srtm processed by cgiar/ciat.
# * timezone : the iana timezone id (see file timeZone.txt) varchar(40)
# * modification date : date of last modification in yyyy-MM-dd format
#
# AdminCodes: Most adm1 are FIPS codes. ISO codes are used for US, CH, BE and ME. UK and Greece are using an additional level between country and fips code. The code '00' stands for general features where no specific adm1 code is defined. The corresponding admin feature is found with the same countrycode and adminX codes and the respective feature code ADMx.

# %%
import pandas as pd

df = pd.read_csv('shared_data/geonames/allCountries.zip', header=None, delimiter='\t', names=('geonameid', 'name', 'asciiname', 'alternatenames', 'latitude', 'longitude', 'feature class',
                     'feature code', 'country code', 'cc2', 'admin1_code', 'admin2_code', 'admin3_code', 'admin4_code',
                     'population', 'elevation', 'dem', 'timezone', 'modification_date'), usecols=('geonameid', 'name', 'latitude', 'longitude', 'feature class',
                     'feature code', 'country code', 'admin1_code', 'admin2_code', 'admin3_code', 'admin4_code',
                     'population', 'elevation', 'modification_date'))
df.sample(100)
# Out:
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (8,10,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           geonameid                      name  latitude  longitude  \
# 8296827     6924192                Zabolotnyy  63.57235   53.63287
# 652699      2801697         Ruisseau de Boeur  50.11667    5.85000
# 1559582     2001882                   Zhaocun  34.53832  109.45965
# 3953183    10212617                    Tirmau  21.92278   78.21223
# 11800894    1002729                   Ga-Titi -25.30000   25.83333
# 10463061    5275995        Towne Country Club  42.83751  -89.06178
# 6299656    11437111            Arroyo Jomulco  24.66257 -106.48585
# 406222      8348232              Brahma Lodge -34.77604  138.65306
# 10210756    5022522  County Ditch Number Four  48.60636  -96.34614
# 9648286     4449136          Underwood Branch  31.31712  -89.01089
# 8979476    10246803  Bay Breeze Hotel Pattaya  12.93168  100.88325
# 1559582              P          PPL           CN          26         NaN
# 3953183              P          PPL           IN          35         447
# 11800894             P          PPL           ZA          10        DC38
# 10463061             S         RSRT           US          WI         105
# 6299656              H         STMI           MX          10         NaN
# 406222               P         PPLX           AU           5       47140
# 10210756             H          CNL           US          MN         135
# 9648286              H          STM           US          MS         111
# 8979476              S          HTL           TH         NaN         NaN
# 11007786             S          NaN           US          WY          31
# 3199239              A         ADM3           GB         WLS          Z1
# 9128203              S         PGDA           TW          04         PEN
# 4402896              P          PPL           IN          36         153
# 7854603              P          PPL           PL          74        1007
# 2710294              L         LCTY           DZ          15         NaN
# 7312289              T           MT           NZ          E9          58
# 347343               S          RSD           AU           2       14870
# 9589531              S          DAM           US          MO         113
# 5605523              T          HLL           MA           4         NaN
# 3369882              P          PPL           HN          05         NaN
# 6468027              H          WLL           NE           7         NaN
# 2074199              P          PPL           CN           9         NaN
# 1501756              P          PPL           CN          29         NaN
# 10818124             H          WLL           US          MT          29
# 5089426              T          HLL           KH          29         NaN
# 4220393              P          PPL           IN          11          23
# 1745352              P          PPL           CN          30         NaN
# 4717144              P          PPL           IR          44         NaN
# ...                ...          ...          ...         ...         ...
# 4381822              P          PPL           IN          38         347
# 4912476              S          HTL           IT          16          AR
# 2984646              H          STM           FJ          00         NaN
# 2574297              A         ADM4           DE           1          81
# 7964174              P         PPLX           PY          22           0
# 8586989              P          PPL           SK           4         NaN
# 3019240              V         FRST           FR          52          44
# 9249013              S           CH           US          AL         085
# 5585983              V         CULT           MA           4         NaN
# 6048305              P          PPL           MX           5          57
# 7223529              P         PPLL           NP          CR           5
# 7271500              P         PPLL           NP          CR           5
# 11172291             A         ADMD           US          OH          65
# 3576174              A         ADM4           ID          30         NaN
# 11023940             S          NaN           US          WY           1
# 9694613              S           CH           US          NC         119
# 10657074             H         RSVT           US          NM          49
# 8552933              T          RKS           SE          28         NaN
# 11159916             S         CMTY           US          GA          15
# 7079133              T          VAL           NO           8        1539
# 5335840              P          PPL           LA           7         NaN
# 4368697              P          PPL           IN          34         226
# 6461596              P          PPL           NE           6         NaN
# 49442                T         SAND           AF          19         NaN
# 7210793              A         ADM5           NP          FR           9
# 9608873              T           MT           US          MO         209
# 1508449              H          RSV           CN          02         NaN
# 8231902              T         CAPE           RU          59         NaN
# 7305404              P          PPL           NZ          F6           1
# 7827836              P          PPL           PK           4         NaN
#
#          admin3_code  admin4_code  population  elevation modification_date
# 8296827          NaN          NaN           0        NaN        2012-01-20
# 652699           NaN          NaN           0        NaN        2010-03-06
# 1559582          NaN          NaN           0        NaN        2012-01-20
# 3953183          NaN          NaN           0        NaN        2016-02-11
# 11800894       NW385          NaN           0        NaN        2012-07-12
# 10463061       22575          NaN           0      254.0        2017-05-23
# 6299656          NaN          NaN           0        NaN        2017-02-05
# 406222           NaN          NaN           0        NaN        2012-07-13
# 10210756         NaN          NaN           0      327.0        2006-01-15
# 9648286          NaN          NaN           0       30.0        2006-01-15
# 8979476          NaN          NaN           0        NaN        2015-05-07
# 11007786         NaN          NaN           0     1813.0        2010-02-19
# 3199239      00NX026          NaN           0        NaN        2010-05-25
# 9128203          X06  1.00161e+10           0        NaN        2017-09-24
# 4402896          NaN          NaN           0        NaN        2016-02-11
# 7854603       100703          NaN           0        NaN        2015-09-05
# 2710294          NaN          NaN           0        NaN        1997-02-27
# 7312289          NaN          NaN           0        NaN        2016-06-22
# 347343           NaN          NaN           0        NaN        2011-06-04
# 9589531        31042          NaN           0      166.0        2017-05-23
# 5605523          NaN          NaN           0        NaN        2016-12-06
# 3369882          NaN          NaN           0        NaN        1993-12-23
# 6468027          NaN          NaN           0        NaN        2009-01-05
# 2074199          NaN          NaN           0        NaN        2015-09-08
# 1501756          NaN          NaN           0        NaN        2000-11-21
# 10818124         NaN          NaN           0      902.0        2006-01-15
# 5089426          NaN          NaN           0      345.0        2012-01-18
# 4220393          NaN          NaN           0        NaN        2016-02-11
# 1745352          NaN          NaN           0        NaN        2012-08-06
# 4717144          NaN          NaN           0        NaN        2014-03-10
# ...              ...          ...         ...        ...               ...
# 4381822          NaN          NaN           0        NaN        2016-02-11
# 4912476        51012          NaN           0        NaN        2015-01-11
# 2984646          NaN          NaN           0        NaN        2016-09-09
# 2574297         8115  8.11505e+06        7424        NaN        2018-04-11
# 7964174          NaN          NaN           0        NaN        2018-04-09
# 8586989          NaN          NaN           0        NaN        2012-01-18
# 3019240          NaN          NaN           0        NaN        2016-02-18
# 9249013          NaN          NaN           0      150.0        2006-01-15
# 5585983          NaN          NaN           0        NaN        2016-12-06
# 6048305          NaN          NaN         141        NaN        2014-04-11
# 7223529           22       220025           0        NaN        2011-08-27
# 7271500           20       200016           0        NaN        2011-08-27
# 11172291         NaN          NaN         875      287.0        2011-05-14
# 3576174          NaN  6.58326e+06           0        NaN        2012-01-20
# 11023940         NaN          NaN           0     2170.0        2010-02-19
# 9694613          NaN          NaN           0      240.0        2010-02-16
# 10657074         NaN          NaN           0     2158.0        2014-10-08
# 8552933          NaN          NaN           0        NaN        2001-06-12
# 11159916         NaN          NaN           0      208.0        2010-02-01
# 7079133          NaN          NaN           0        NaN        2014-10-13
# 5335840          NaN          NaN           0        NaN        2016-09-09
# 4368697          NaN          NaN           0        NaN        2016-02-11
# 6461596          NaN          NaN           0        NaN        2012-01-20
# 49442            NaN          NaN           0        NaN        2012-01-19
# 7210793           75       750029           0        NaN        2012-02-08
# 9608873        63766          NaN           0      403.0        2017-05-23
# 1508449          NaN          NaN           0        NaN        2012-01-18
# 8231902          NaN          NaN           0        NaN        2012-10-06
# 7305404          NaN          NaN           0        NaN        2011-08-01
# 7827836          NaN          NaN           0        NaN        2018-05-12
#
# [100 rows x 14 columns]

# %% [markdown]
# ### Question 1
#
# Quel est la taille du DataFrame?

# %%
df.shape
# Out:
# (11897027, 14)

# %% [markdown]
# ### Question 2
#
# Afficher le résumé des veleurs du DataFrame

# %%
df.describe()
# Out:
#           geonameid      latitude     longitude    population     elevation
# count  1.189703e+07  1.189703e+07  1.189703e+07  1.189703e+07  2.359496e+06
# mean   6.023458e+06  2.829223e+01  1.212834e+01  4.314231e+03  5.618345e+02
# std    3.478550e+06  2.368156e+01  8.040919e+01  2.650591e+06  7.287861e+02
# min    3.000000e+00 -9.000000e+01 -1.799995e+02 -1.200000e+01 -1.091100e+04
# 25%    3.011316e+06  1.671923e+01 -7.455850e+01  0.000000e+00  1.090000e+02
# 50%    6.005998e+06  3.325595e+01  1.683333e+01  0.000000e+00  2.630000e+02
# 75%    9.037462e+06  4.380352e+01  8.068333e+01  0.000000e+00  6.790000e+02
# max    1.203626e+07  9.000000e+01  1.800000e+02  6.814400e+09  8.848000e+03

# %% [markdown]
# ### Question 3
#
# Quels sont les lacs qui figurent dans les données? (*aide : code "LK"*)
#
# *Bonus : Y a-t-il des doublons ? *

# %%
lacs = df.loc[df['feature code'] == 'LK']
lacs[['geonameid', 'name', 'country code']].sort_values(by='name')
# Out:
#           geonameid                    name country code
# 10204146    5015768   'R' Lake (historical)           US
# 6637930     9039959              1.Porsvatn           NO
# 11001377    5816742        1000 Island Lake           US
# 892973      5881640           101 Mile Lake           CA
# 892975      5881642           103 Mile Lake           CA
# 892977      5881644           105 Mile Lake           CA
# 892980      5881647           108 Mile Lake           CA
# 892993      5881660           130 Mile Lake           CA
# 892999      5881666        16 1/2 Mile Lake           CA
# 893001      5881668                180 Lake           CA
# 9299680     4099011       1927 Cut-off Lake           US
# 6565194     7115020               1e Diemen           NL
# 10172164    4983705                  2 Lake           US
# 893012      5881680            24 Mile Lake           CA
# 10769498    5583683            26 Mile Lake           US
# 893015      5881683            28 Mile Lake           CA
# 6565195     7115021               2e Diemen           NL
# 10172165    4983706                  3 Lake           US
# 893032      5881701             4 Mile Lake           CA
# 893030      5881699                 49 Lake           CA
# 893034      5881703                 51 Lake           CA
# 893037      5881706                 54 Lake           CA
# 893039      5881708                 55 Lake           CA
# 893045      5881714             6 Mile Lake           CA
# 893049      5881719                  7e Lac           CA
# 10172166    4983707                  8 Lake           US
# 893055      5881725                  9e Lac           CA
# 9345899     4145526         A A Hilton Pond           US
# 9345902     4145529      A Bar H Ranch Pond           US
# 9345914     4145541    A J Kennedy Pond One           US
# ...             ...                     ...          ...
# 8771763     6692153            ทะเลสาบสงขลา           TH
# 38806       1348156            Ḏanḏ-e Zenōr           AF
# 67344       1465246              Ḩalqah Kōl           AF
# 76930       1476562            Ḩowẕ-e Bōkōs           AF
# 32822       1143984  Ḩowẕ-e Darah-ye Kishtī           AF
# 68478       1466797   Ḩowẕ-e Darah-ye Sakhī           AF
# 70988       1469355             Ḩowẕ-e Ghāt           AF
# 60243       1456012  Ḩowẕ-e Ghāt-e Chashmah           AF
# 60237       1456004  Ḩowẕ-e Ghāt-e Sêpirmay           AF
# 60241       1456008   Ḩowẕ-e Ghāt-e Warmanā           AF
# 29926       1141065           Ḩowẕ-e Ghūjān           AF
# 60224       1455990         Ḩowẕ-e Kamanduk           AF
# 26224       1137336          Ḩowẕ-e Khakhun           AF
# 58762       1454504             Ḩowẕ-e Khāş           AF
# 73378       1471900             Ḩowẕ-e Khāş           AF
# 44620       1427716       Ḩowẕ-e Kāfarzadah           AF
# 46055       1429524       Ḩowẕ-e Muhim Khān           AF
# 21281       1132348              Ḩowẕ-e Nār           AF
# 60194       1455959           Ḩowẕ-e Rowunj           AF
# 60195       1455960        Ḩowẕ-e Sangbōnah           AF
# 15923       1126948          Ḩowẕ-e Sar Jar           AF
# 68179       1466493             Ḩowẕ-e Shōr           AF
# 10629       1121582          Ḩowẕ-e Wīghnān           AF
# 8452408      373699                Ḩumayyir           SD
# 8457331      380294        ‘Adad al Gauwala           SD
# 2894413      344269          ‘Alemaya Hāyk’           ET
# 11038181    5853862             ‘Uko‘a Pond           US
# 6546984     2746515           ’t Bovenwater           NL
# 6546723     2746244       ’t Nije Hemelriek           NL
# 1571830     6252031                     七里湖           CN
#
# [267248 rows x 3 columns]

# %%
# compraraison avec le nombre de IDs uniques
lacs_ids = lacs['geonameid'].nunique()
if lacs.shape[0] == lacs_ids :
    print ('Il n\'y a pas de douoblons')
else :
    print ('Il n\'y a pas de douoblons')
print ('nombre de ids : ' + str(lacs_ids))
# Out:
# Il n'y a pas de douoblons
# nombre de ids : 267248

# %% [markdown]
# ### Question 4
#
# Afficher le nombre de lacs par pays

# %%
lacs_par_pays = lacs['country code'].value_counts()
lacs_par_pays
# Out:
# CA    104664
# US     69290
# RU     16225
# NO     12461
# SE     10865
# FI      4957
# MZ      4033
# AU      3802
# PE      3480
# DE      2525
# LT      2360
# KZ      1800
# BR      1590
# IE      1552
# ID      1537
# MX      1261
# AR      1220
# CO      1209
# CN      1165
# NZ      1157
# CH      1140
# PL      1063
# VE      1013
# IN       979
# GB       819
# BY       763
# IS       607
# CL       597
# LV       570
# BO       558
#        ...
# YT         3
# LB         3
# CK         3
# TT         2
# FM         2
# JM         2
# WF         2
# GU         2
# SR         2
# LI         2
# BN         2
# GQ         2
# DM         2
# SG         2
# KI         2
# VC         1
# NR         1
# YE         1
# KN         1
# CW         1
# CY         1
# DJ         1
# GF         1
# LS         1
# MV         1
# BW         1
# HK         1
# JO         1
# GW         1
# JE         1
# Name: country code, Length: 202, dtype: int64

# %% [markdown]
# ### Question 5
#
# Quels sont les lacs repertoriés pour la Suisse et quel est son altitude moyenne ?
#
# *Bonus : Et pour le Canton de Genève ?*

# %%
lacs_ch = lacs.loc[lacs['country code'] == 'CH']
lacs_ch.sort_values(by='name')
# Out:
#          geonameid              name  latitude  longitude feature class  \
# 1352440   11396381        Aatalweier  47.23978    8.95145             H
# 1352307   11396247      Acqua Fredda  46.42735    8.54427             H
# 1353177   11397122       Adligeweier  47.09082    8.28545             H
# 1353109   11397054         Albulasee  46.58389    9.84796             H
# 1353186   11397131     Allmendweiher  47.30588    7.84221             H
# 1353289   11397234     Allmendweiher  47.30547    7.84349             H
# 1353034   11396979         Ängiwäier  47.70220    8.60738             H
# 1352555   11396497        Übeschisee  46.73393    7.56498             H
# 1352713   11396657           Üelisee  46.53292    8.28613             H
# 1353146   11397091   Üssersts Seewji  46.23859    7.80638             H
#
#         feature code country code admin1_code admin2_code admin3_code  \
# 1352440           LK           CH          SG        1726        3342
# 1352307           LK           CH          TI        2108        5310
# 1353177           LK           CH          LU         313        1024
# 1353109           LK           CH          GR        1846        3785
# 1353186           LK           CH          SO        1108        2578
# 1353289           LK           CH          SO        1108        2578
# 1353249           LK           CH          UR         400        1217
# 1352569           LK           CH          UR         400        1219
# 1353045           LK           CH          SG        1723        3234
# 1352427           LK           CH          BE         242         746
# 1353006           LK           CH          GR        1848        3921
# 1352351           LK           CH          SG        1723        3234
# 1353148           LK           CH          GR        1850        3603
# 1301426           LK           CH          BE         NaN         NaN
# 1352554           LK           CH          TG        2012        4816
# 1353293           LK           CH          BE         250         576
# 1353143           LK           CH          BE         250         576
# 1352492           LK           CH          BE         250         576
# 1352942           LK           CH          VS        2309        6192
# 1301391           LK           CH          BE         NaN         NaN
# 1352698           LK           CH          UR         400        1209
# 1353282           LK           CH          OW         600        1403
# 1352810           LK           CH          BE         249         565
# 1352832           LK           CH          BE         249         565
# 1353319           LK           CH          BE         244         334
# 1353210           LK           CH          GR        1849        3871
# 1308804           LK           CH          ZH         NaN         NaN
# 1352383           LK           CH          BE         250         576
# 1352281           LK           CH          ZH         105         120
# 1352614           LK           CH          BE         250         572
# ...              ...          ...         ...         ...         ...
# 1352836           LK           CH          VS        2311        6239
# 1352474           LK           CH          SG        1721        3203
# 1352901           LK           CH          SG        1724        3271
# 1353102           LK           CH          OW         600        1407
# 1353061           LK           CH          UR         400        1215
# 1353256           LK           CH          UR         400        1202
# 1353254           LK           CH          ZH         108         296
# 1352340           LK           CH          ZG         900        1704
# 1352646           LK           CH          VS        2304        6052
# 1352750           LK           CH          VS        2306        6117
# 1353202           LK           CH          BE         250         580
# 1352557           LK           CH          SG        1726        3342
# 1297845           LK           CH          SZ         NaN         NaN
# 1352903           LK           CH          VS        2306        6110
# 1352328           LK           CH          GR        1850        3603
# 1297651           LK           CH          00         NaN         NaN
# 1353151           LK           CH          VS        2301        6011
# 1353245           LK           CH          VS        2304        6054
# 1297660           LK           CH          00         NaN         NaN
# 1353195           LK           CH          AG        1902        4023
# 1352280           LK           CH          BE         249         762
# 1353179           LK           CH          AG        1909        4263
# 1301506           LK           CH          ZG         NaN         NaN
# 1353206           LK           CH          GR        1848        3921
# 1353239           LK           CH          UR         400        1208
# 1352974           LK           CH          LU         316        1004
# 1353034           LK           CH          SH        1403        2939
# 1352555           LK           CH          BE         247         770
# 1352713           LK           CH          VS        2304        6076
# 1353146           LK           CH          VS        2313        6296
#
#         admin4_code  population  elevation modification_date
# 1352440         NaN           0        NaN        2016-12-27
# 1352307         NaN           0        NaN        2016-12-27
# 1353177         NaN           0        NaN        2016-12-27
# 1353109         NaN           0        NaN        2017-07-28
# 1352317   11396257  Etang du Moulin de Vert  46.18023    6.02105
# 1352982   11396926         Barrage du Rhône  46.19614    6.04785
#
#         feature class feature code country code admin1_code admin2_code  \
# 1352314             H           LK           CH          GE        2500
# 1352317             H           LK           CH          GE        2500
# 1352982             H           LK           CH          GE        2500
#
#         admin3_code admin4_code  population  elevation modification_date
# 1352314        6609         NaN           0        NaN        2016-12-27
# 1352317        6609         NaN           0        NaN        2016-12-27
# 1352982        6638         NaN           0        NaN        2016-12-27

# %%
lacs_ch.loc[lacs_ch['admin1_code'] == 'GE']['elevation'].mean()
# Out:
# nan

# %% [markdown]
# ### Question 6
#
# Identifier le lac Léman

# %%
lacs[lacs['name'].str.contains('Geneva')].sort_values(by='name')
# Out:
#           geonameid                name  latitude  longitude feature class  \
# 971446      5960266         Geneva Lake  46.76451  -81.54622             H
# 10609431    5422870         Geneva Lake  39.57063 -105.82117             H
# 10609424    5422863         Geneva Lake  39.09698 -107.07756             H
# 10182235    4993798         Geneva Lake  42.64384  -83.36583             H
# 10182234    4993797         Geneva Lake  42.61755  -85.63163             H
# 971447      5960267         Geneva Lake  53.49639 -111.18333             H
# 9356999     4156662         Lake Geneva  28.50295  -82.18297             H
# 10874473    5689265         Lake Geneva  46.84090 -100.02012             H
# 10839432    5653983         Lake Geneva  48.98167 -115.41216             H
# 10839431    5653982         Lake Geneva  45.25162 -113.65567             H
# 1300346     2660647         Lake Geneva  46.43774    6.46906             H
# 10446268    5259170         Lake Geneva  42.56501  -88.50375             H
# 10305969    5118401         Lake Geneva  41.92841  -73.72466             H
# 10215943    5027791         Lake Geneva  45.89931  -95.32744             H
# 9356998     4156661         Lake Geneva  29.76608  -82.02260             H
# 10182239    4993802         Lake Geneva  45.17898  -84.21483             H
# 9264715     4063948         Lake Geneva  31.02712  -85.84967             H
# 10980121    5795351         Lake Geneva  47.29153 -122.28131             H
# 9357004     4156667         Lake Geneva  28.74405  -81.10875             H
# 9357003     4156666         Lake Geneva  28.14924  -81.60677             H
# 9357002     4156665         Lake Geneva  28.18799  -82.57312             H
# 9357001     4156664         Lake Geneva  28.92979  -81.67074             H
# 9357000     4156663         Lake Geneva  28.88063  -81.91585             H
# 10182238    4993801         Lake Geneva  42.83387  -84.58303             H
# 11010481    5825907         Lake Geneva  44.46602 -107.25162             H
# 9362587     4162269  Little Lake Geneva  29.79779  -82.00473             H
#
#          feature code country code admin1_code admin2_code admin3_code  \
# 971446             LK           CA           8        3552         NaN
# 10609431           LK           US          CO          19         NaN
# 10609424           LK           US          CO          51         NaN
# 10182235           LK           US          MI         125         NaN
# 10182234           LK           US          MI           5         NaN
# 971447             LK           CA           1         NaN         NaN
# 9356999            LK           US          FL          53         NaN
# 10874473           LK           US          ND          43         NaN
# 10839432           LK           US          MT          53         NaN
# 10839431           LK           US          MT           1         NaN
# 1300346            LK           CH          00         NaN         NaN
# 10446268           LK           US          WI         127         NaN
# 10305969           LK           US          NY          27         NaN
# 10215943           LK           US          MN          41         NaN
# 9356998            LK           US          FL          19         NaN
# 10182239           LK           US          MI         119         NaN
# 9264715            LK           US          AL         061         NaN
# 10980121           LK           US          WA          33         NaN
# 9357004            LK           US          FL         117         NaN
# 9357003            LK           US          FL         105         NaN
# 9357002            LK           US          FL         101         NaN
# 9357001            LK           US          FL          69         NaN
# 9357000            LK           US          FL          69         NaN
# 10182238           LK           US          MI          37         NaN
# 11010481           LK           US          WY          19         NaN
# 9362587            LK           US          FL          19         NaN
#
#          admin4_code  population  elevation modification_date
# 971446           NaN           0        NaN        2018-01-20
# 10609431         NaN           0     3537.0        2011-12-11
# 10609424         NaN           0     3335.0        2011-12-11
# 10182235         NaN           0      284.0        2011-12-11
# 10182234         NaN           0      248.0        2011-12-11
# 971447           NaN           0        NaN        2013-07-21
# 9356999          NaN           0       17.0        2014-10-07
# 10874473         NaN           0      550.0        2014-10-08
# 10839432         NaN           0     1995.0        2014-10-07
# 10839431         NaN           0     2577.0        2011-12-11
# 1300346          NaN           0      372.0        2011-02-23
# 10446268         NaN           0      263.0        2014-10-08
# 10305969         NaN           0      149.0        2011-12-11
# 10215943         NaN           0      412.0        2011-12-11
# 9356998          NaN           0       30.0        2007-02-14
# 10182239         NaN           0      250.0        2011-12-11
# 9264715          NaN           0       28.0        2011-12-11
# 10980121         NaN           0      113.0        2011-12-12
# 9357004          NaN           0        8.0        2011-12-11
# 9357003          NaN           0       34.0        2014-10-07
# 9357002          NaN           0       16.0        2011-12-11
# 9357001          NaN           0       22.0        2011-12-11
# 9357000          NaN           0       25.0        2014-10-07
# 10182238         NaN           0      248.0        2011-12-11
# 11010481         NaN           0     2831.0        2013-03-08
# 9362587          NaN           0       23.0        2016-12-06

# %%
lacs[(lacs['name'].str.contains('Geneva')) & (lacs['country code'] == 'CH')].sort_values(by='name')
# Out:
#          geonameid         name  latitude  longitude feature class  \
# 1300346    2660647  Lake Geneva  46.43774    6.46906             H
#
#         feature code country code admin1_code admin2_code admin3_code  \
# 1300346           LK           CH          00         NaN         NaN
#
#         admin4_code  population  elevation modification_date
# 1300346         NaN           0      372.0        2011-02-23

# %%
lacs[lacs['geonameid'] == 2660647]
# Out:
#          geonameid         name  latitude  longitude feature class  \
# 1300346    2660647  Lake Geneva  46.43774    6.46906             H
#
#         feature code country code admin1_code admin2_code admin3_code  \
# 1300346           LK           CH          00         NaN         NaN
#
#         admin4_code  population  elevation modification_date
# 1300346         NaN           0      372.0        2011-02-23

# %% [markdown]
# ### Question 7
#
# Exporter la table des lacs dans un fichier CSV

# %%
lacs.to_csv('lacs.tsv', sep='\t', encoding='utf-8', index=False)

# %% [markdown]
# ### Question 8
#
# Afficher un graphique des barres avec le nombre de lacs par pays pour les premiers 30 pays
#
# *Bonus : Afficher un histogramme avec l'altitude des lacs et la même chose pour les lacs de Suisse*

# %%
import matplotlib as plt  
# %matplotlib inline

lacs_par_pays[0:30].plot.bar()

# %%
lacs['elevation'].plot.hist()

# %%
# idem pour la Suisse
lacs_ch['elevation'].plot.hist()
