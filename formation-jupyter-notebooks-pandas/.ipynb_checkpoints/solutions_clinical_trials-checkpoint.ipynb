# %% [markdown]
# # Introduction à Pandas : exercices
#
#
# ## Données d'exemple : Clinical trials
#
# source: https://clinicaltrials.gov/ct2/resources/download
#
# Fichiers de 10'000 lignes téléchargés avec curl :
#
# curl https://clinicaltrials.gov/ct2/results/download_fields\?down_count=10000\&down_fmt=tsv\&down_chunk=[1-50] -m 300 -o "clinical_trials_#1.tsv"

# %%
import os
import pandas as pd
my_total = 0
df = pd.DataFrame()
for file in os.listdir('shared_data/clinical_trials'):
    print (file)
    myfile = 'shared_data/clinical_trials/' + file
    df_temp = pd.read_csv(myfile, sep='\t')
    df = pd.concat([df, df_temp], ignore_index=True)
df.sample(100)
# Out:
# clinical_trials_1.tsv
# clinical_trials_10.tsv
# clinical_trials_11.tsv
# clinical_trials_12.tsv
# clinical_trials_13.tsv
# clinical_trials_14.tsv
# clinical_trials_15.tsv
# clinical_trials_16.tsv
# clinical_trials_17.tsv
# clinical_trials_18.tsv
# clinical_trials_19.tsv
# clinical_trials_2.tsv
# clinical_trials_20.tsv
# clinical_trials_21.tsv
# clinical_trials_22.tsv
# clinical_trials_23.tsv
# clinical_trials_24.tsv
# clinical_trials_25.tsv
# clinical_trials_26.tsv
# clinical_trials_27.tsv
# clinical_trials_28.tsv
# clinical_trials_29.tsv
# clinical_trials_3.tsv
# clinical_trials_30.tsv
# clinical_trials_31.tsv
# clinical_trials_4.tsv
# clinical_trials_5.tsv
# clinical_trials_6.tsv
# clinical_trials_7.tsv
# clinical_trials_8.tsv
# clinical_trials_9.tsv
#           Rank                                              Title  \
# 44440   124920           Post-MI PET Scan Imaging of Inflammation
# 60902   141599  Comparison of Clinical Performance of the Guar...
# 294379   83023  Comparison Between Injections of Steroids and ...
# 35215   115419  Prospective Assessment of the Rockall Risk Sco...
# 102632  183329  Testing a Spanish Version of a Patient Toxicit...
# ...        ...                                                ...
# 156202  227128  Stereotactic Body Radiotherapy (SBRT) for Pros...
# 114467   15381  A Methodology Development Clinical Trial of Re...
# 103987  184684  A Multi-center, Randomized, Double-blind Phase...
# 174477  245403  The Effect of Acute and Chronic Exercise at th...
# 164298  235224  5 mg Glipizide/500 mg Metformin Hydrochloride ...
#
#                         Status         Study Results  \
# 44440           Unknown status  No Results Available
# 60902                Completed           Has Results
# 294379               Completed  No Results Available
# 35215                Completed  No Results Available
# 102632               Completed  No Results Available
# ...                        ...                   ...
# 156202  Active, not recruiting  No Results Available
# 114467              Recruiting  No Results Available
# 103987               Completed  No Results Available
# 174477          Unknown status  No Results Available
# 164298               Completed           Has Results
#
#                                                Conditions  \
# 44440                         Acute Myocardial Infarction
# 60902             Efficacy of Oropharyngeal Seal Pressure
# 294379                            Oral Pemphigus Vulgaris
# 35215                           Gastrointestinal Bleeding
# 102632  Breast Cancer|Colon Cancer|Lung Cancer|Lymphom...
# ...                                                   ...
# 156202                                    Prostate Cancer
# 114467                           Conjunctivitis, Allergic
# 103987                                Erosive Esophagitis
# 174477                                    Obesity|Healthy
# 164298                                            Healthy
#
#                                             Interventions  \
# 44440                                    Drug: Colchicine
# 60902   Device: Guardian Laryngeal Mask|Device: Prosea...
# 294379  Other: Autologous Platelet rich plasma|Drug: T...
# 35215             Other: Upper gastrointestinal endoscopy
# 102632                                                NaN
# ...                                                   ...
# 156202                           Radiation: SBRT Prostate
# 114467  Drug: Reproxalap Ophthalmic Solution (0.25%)|D...
# 103987  Drug: Lafutidine|Drug: Famotidine|Drug: Omepra...
# 174477  Behavioral: Exercise-only (EXO-12 weeks of reg...
# 164298  Drug: 5 mg/500 mg METAGLIP™ Tablets|Drug: 5 mg...
#
#                                                 Locations  \
# 44440   Athens General Hospital "G. Gennimatas", Athen...
# 60902   Tianjin Medical University General Hospital, T...
# 294379  Faculty of Medicine Cairo University Dermatolo...
# 35215   Egypt Ain Shams center University Hospitals, C...
# 102632  National Cancer Institute (NCI), 9000 Rockvill...
# ...                                                   ...
# 156202  Duke University Medical Center, Durham, North ...
# 114467  Inflamax Research Limited, Mississauga, Ontari...
# 103987                                                NaN
# 174477  Department of Medicine and Endocrinology C, Aa...
# 164298  PRACS Institute Ltd., East Grand Forks, Minnes...
#
#                                                 URL
# 44440   https://ClinicalTrials.gov/show/NCT02281305
# 60902   https://ClinicalTrials.gov/show/NCT02063516
# 294379  https://ClinicalTrials.gov/show/NCT02828163
# 35215   https://ClinicalTrials.gov/show/NCT02405286
# 102632  https://ClinicalTrials.gov/show/NCT01517152
# ...                                             ...
# 156202  https://ClinicalTrials.gov/show/NCT00941915
# 114467  https://ClinicalTrials.gov/show/NCT03709121
# 103987  https://ClinicalTrials.gov/show/NCT01499368
# 174477  https://ClinicalTrials.gov/show/NCT00700245
# 164298  https://ClinicalTrials.gov/show/NCT00834587
#
# [100 rows x 8 columns]

# %%
df
# Out:
#          Rank                                              Title  \
# 0           1  Glycaemic Markers in Persons With Type 2 Diabe...
# 1           2  NUTRI-HAB - Posttreatment Rehabilitation of Nu...
# 2           3  Assessment of Child Psychological Attributes f...
# 3           4  Endometrial Fluid Study in Natural Cycles: a P...
# 4           5  Treating Depression With Transcutaneous Electr...
# ...       ...                                                ...
# 301329  89996  Tobacco Cessation Intervention Study for Oral ...
# 301330  89997          Strata Programmable CSF Shunt Valve Study
# 301331  89998  SecOnd-generation seLf-expandable Versus Ballo...
# 301332  89999  Dynamic Multimodal Monitoring for Ultrasound G...
# 301333  90000          Acetaminophen Randomized Controlled Trial
#
#                         Status         Study Results  \
# 0                   Recruiting  No Results Available
# 1           Not yet recruiting  No Results Available
# 2           Not yet recruiting  No Results Available
# 3                   Recruiting  No Results Available
# 4           Not yet recruiting  No Results Available
# ...                        ...                   ...
# 301329          Unknown status  No Results Available
# 301330              Recruiting  No Results Available
# 301331  Active, not recruiting  No Results Available
# 301332          Unknown status  No Results Available
# 301333               Withdrawn  No Results Available
#
#                                                Conditions  \
# 0              Diabetic Nephropathy Type 2|Type2 Diabetes
# 1                                    Head and Neck Cancer
# 2                                 Psychological Disorders
# 3                                       Endometrial Fluid
# 4                             Mild-to-moderate Depression
# ...                                                   ...
# 301329  Smoking Cessation|Mouth Diseases|Periodontal D...
# 301330                                      Hydrocephalus
# 301331                                    Aortic Stenosis
# 301332                                 Orthopedic Surgery
# 301333                                Post Operative Pain
#
#                                             Interventions  \
# 0       Device: Continuous glucose monitoring|Diagnost...
# 1                                        Other: NUTRI-HAB
# 2                                                     NaN
# 3                                                     NaN
# 4       Procedure: TECAS Procedure|Drug: Escitalopram|...
# ...                                                   ...
# 301329              Other: Tobacco cessation intervention
# 301330                                                NaN
# 301331  Device: CoreValve Evolut R|Device: Edwards Sap...
# 301332  Procedure: Manual measurement|Procedure: Measu...
# 301333                 Drug: Acetaminophen|Other: Placebo
#
#                                                 Locations  \
# 0                    Rigshospitalet, København Ø, Denmark
# 1                                                     NaN
# 2                                                     NaN
# 3                    IVIRMA Bilbao, Leioa, Vizcaya, Spain
# 4       Department of Chinese Medicine, The University...
# ...                                                   ...
# 301329  Okazaki City Hospital, Okazaki, Aichi, Japan|S...
# 301330  Johns Hopkins All Children's Hospital, Saint P...
# 301331            University of Luebeck, Luebeck, Germany
# 301332               CHOQUET, France, Montpellier, France
# 301333  New York University Medical Center, New York, ...
#
#                                                 URL
# 0       https://ClinicalTrials.gov/show/NCT03909269
# 1       https://ClinicalTrials.gov/show/NCT03909256
# 2       https://ClinicalTrials.gov/show/NCT03909243
# 3       https://ClinicalTrials.gov/show/NCT03909230
# 4       https://ClinicalTrials.gov/show/NCT03909217
# ...                                             ...
# 301329  https://ClinicalTrials.gov/show/NCT02737176
# 301330  https://ClinicalTrials.gov/show/NCT02737163
# 301331  https://ClinicalTrials.gov/show/NCT02737150
# 301332  https://ClinicalTrials.gov/show/NCT02737137
# 301333  https://ClinicalTrials.gov/show/NCT02737124
#
# [301334 rows x 8 columns]

# %% [markdown]
# ### Question 1
#
# Quel est la taille du DataFrame?

# %%
df.shape
# Out:
# (301334, 8)

# %% [markdown]
# ### Question 2
#
# Quels sont la fréquence maladies qui figurent dans les données? (*aide : champ "Conditions")

# %%
df['Conditions'].value_counts()
# Out:
# Conditions
# Healthy                                                                                              6015
# Breast Cancer                                                                                        3426
# Prostate Cancer                                                                                      2061
# Asthma                                                                                               1946
# HIV Infections                                                                                       1872
#                                                                                                      ...
# Acellular Pertussis|Diphtheria|Tetanus|Poliomyelitis                                                    1
# Myopathic Symptoms                                                                                      1
# Laparoscopic Gynecologic, Abdominal, Other Surgery|General Anesthesia                                   1
# Safety|Pharmacokinetics                                                                                 1
# Smoking Cessation|Mouth Diseases|Periodontal Diseases|Leukoplakia|Lichen Planus|Keratosis|Implant       1
# Name: count, Length: 113218, dtype: int64

# %% [markdown]
# ### Question 3
#
# Afficher les valeurs du champ Status

# %%
status = df['Status'].value_counts()
df_status = pd.DataFrame.from_dict(status)
df_status
# Out:
#                                                      count
# Status
# Completed                                           160659
# Recruiting                                           49877
# Unknown status                                       31269
# Terminated                                           16996
# Active, not recruiting                               16333
# Not yet recruiting                                   13110
# Withdrawn                                             7431
# Enrolling by invitation                               3265
# Suspended                                             1049
# Withheld                                               784
# No longer available                                    215
# Available                                              205
# Approved for marketing                                 112
# Temporarily not available                               22
# https://ClinicalTrials.gov/show/NCT02349906              1
# https://ClinicalTrials.gov/show/NCT02247882              1
# Department of Clinical Medicine, Sapienza Unive...       1
# https://ClinicalTrials.gov/show/NCT01492101              1
# https://ClinicalTrials.gov/show/NCT00235755              1
# https://ClinicalTrials.gov/show/NCT03238326              1
# https://ClinicalTrials.gov/show/NCT03180840              1

# %% [markdown]
# ### Question 4
#
# Afficher les 10 premiers valeurs du champ Status dans un diagrame camembert

# %%
# garder les 10 premiers valeurs
df_status = df_status[:10]
df_status
# Out:
#                           count
# Status
# Completed                160659
# Recruiting                49877
# Unknown status            31269
# Terminated                16996
# Active, not recruiting    16333
# Not yet recruiting        13110
# Withdrawn                  7431
# Enrolling by invitation    3265
# Suspended                  1049
# Withheld                    784

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig1, ax1 = plt.subplots()
ax1.pie(df_status['count'], startangle=90, labels=df_status.index)
ax1.axis('equal')
plt.show()

# %% [markdown]
# ### Question 5
#
# Afficher les essais faits à Genève

# %%
df.loc[df['Locations'].str.contains(r"Geneva", na=False)]
# Out:
#          Rank                                              Title  \
# 597       598                       DD Assessment With Diaana #2
# 1234     1235                            The SwissPrEPared Study
# 1446     1447  GLUCOSAFE 2 - A New Tool for Nutritional Manag...
# 1985     1986  Frailty and Complexity Among Home Service Reci...
# 4631     4632  Impact of Simulation Training for Obstetrics-g...
# ...       ...                                                ...
# 298789  87456             Effect of Personalized Robotic Therapy
# 298802  87469  Chart Review of Repatha® in Subjects With Hype...
# 299550  88217  Extrahepatic Insulin Resistance in Chronic Hep...
# 299728  88395  A Study to Evaluate Sebacia Microparticles in ...
# 300280  88947       Breast Cancer WEight Loss Study (BWEL Study)
#
#                         Status         Study Results  \
# 597                 Recruiting  No Results Available
# 1234        Not yet recruiting  No Results Available
# 1446        Not yet recruiting  No Results Available
# 1985                Recruiting  No Results Available
# 4631                Recruiting  No Results Available
# ...                        ...                   ...
# 298789              Recruiting  No Results Available
# 298802              Recruiting  No Results Available
# 299550  Active, not recruiting  No Results Available
# 299728               Completed  No Results Available
# 300280              Recruiting  No Results Available
#
#                                                Conditions  \
# 597     Decision Making|Computer-assisted|General Prac...
# 1234                          HIV Preexposure Prophylaxis
# 1446    Critical Illness|Energy Supply; Deficiency, Se...
# 1985                               Frail Elderly Syndrome
# 4631                                  Simulation Training
# ...                                                   ...
# 298789                                             Stroke
# 298802                              Hypercholesterolaemia
# 299550                                 Insulin Resistance
# 299728                               Facial Acne Vulgaris
# 300280                                   Breast Carcinoma
#
#                                             Interventions  \
# 597                                         Other: Diaana
# 1234                                                  NaN
# 1446    Device: GLUCOSAFE 2|Device: Local protocol con...
# 1985                       Other: interRAI-HC assessments
# 4631    Other: Simulation training for ECV|Other: Simu...
# ...                                                   ...
# 298789  Device: Arm Light Exoskeleton Rehab Station (A...
# 298802                                                NaN
# 299550  Drug: Ledipasvir 90 mg/Sofosbuvir 400 mg|Drug:...
# 299728                     Device: Sebacia Microparticles
# 300280  Other: Health Education Program|Other: Weight ...
#
#                                                 Locations  \
# 597       Geneva University Hospital, Geneva, Switzerland
# 1234    University Hospital Basel, Basel, Basel-Stadt,...
# 1446    Service of Intensive Care, Geneva University H...
# 1985    School of Health Sciences Geneva, Geneva, Swit...
# 4631    Gynecology & obstetrics department of Geneva U...
# ...                                                   ...
# 298789  University Hospital of Geneva, Geneva, Switzer...
# 298802  Research Site, Feldkirch, Austria|Research Sit...
# 299550  Division of Gastroenterology and hepatology, U...
# 299728  Lasercenter North, Aalborg, Denmark|Department...
# 300280  Southern Cancer Center PC-Daphne, Daphne, Alab...
#
#                                                 URL
# 597     https://ClinicalTrials.gov/show/NCT03901495
# 1234    https://ClinicalTrials.gov/show/NCT03893188
# 1446    https://ClinicalTrials.gov/show/NCT03890432
# 1985    https://ClinicalTrials.gov/show/NCT03883425
# 4631    https://ClinicalTrials.gov/show/NCT03848975
# ...                                             ...
# 298789  https://ClinicalTrials.gov/show/NCT02770300
# 298802  https://ClinicalTrials.gov/show/NCT02770131
# 299550  https://ClinicalTrials.gov/show/NCT02760355
# 299728  https://ClinicalTrials.gov/show/NCT02758041
# 300280  https://ClinicalTrials.gov/show/NCT02750826
#
# [885 rows x 8 columns]

# %% [markdown]
# ### Question 6
#
# Exporter la table essais faits à Genève dans un fichier CSV

# %%
df.loc[df['Locations'].str.contains(r"Geneva", na=False)].to_csv('clinical_trials_geneva.csv', index=False)
